# %%
require(data.table)
require(dada2)
require(phyloseq)
require(DESeq2)
require(genefilter)
require(ggplot2)
require(vegan)
require(RColorBrewer)
require(metacoder)
options(repr.plot.width=20, repr.plot.height=15)
# Out:
# Loading required package: data.table
#
# Loading required package: dada2
#
# Loading required package: Rcpp
#
# Loading required package: phyloseq
#
# Loading required package: DESeq2
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:phyloseq’:
#
#     distance
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
# The following object is masked from ‘package:phyloseq’:
#
#     sampleNames
#
#
# Loading required package: genefilter
#
#
# Attaching package: ‘genefilter’
#
#
# The following objects are masked from ‘package:MatrixGenerics’:
#
#     rowSds, rowVars
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     rowSds, rowVars
#
#
# Loading required package: ggplot2
#
# Loading required package: vegan
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.6-2
#
# Loading required package: RColorBrewer
#
# Loading required package: metacoder
#
# This is metacoder verison 0.3.5 (stable)
#
#
# Attaching package: ‘metacoder’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     map_data
#
#
# The following object is masked from ‘package:IRanges’:
#
#     reverse
#
#
# The following object is masked from ‘package:phyloseq’:
#
#     filter_taxa

# %%
meta=fread("~/Documents/DE/DE_16S/DE16S_allmeta.csv")
asv_all=fread("~/Documents/DE/DE_16S/ASVs/Run123_ASV_nochim.csv")
taxa=read.csv("~/Documents/DE/DE_16S/ASVs/Run123_taxa.csv", header=TRUE, row.names=1)

# %%
#make RFTM presence absence
meta$RFTM_pa=ifelse(meta$RFTM_score=="0", 0, 1)
meta$RFTM_pa=factor(meta$RFTM_pa)

# %%
#fix rownames
rows=as.vector(asv_all[,1])
asv_all=asv_all[,-1]
asv_all=apply(asv_all, 2, as.numeric)
row.names(asv_all)=rows$V1

# %%
#pull out the dilution effect samples
meta_de=meta[meta$Experiment=="Field17"|meta$Experiment=="Lab18",]

# %%
meta_de17=meta[meta$Experiment=="Field17",]

# %%
asv_de17=asv_all[rownames(asv_all) %in% meta_de17$UniqueID,]

# %%
meta_de18=meta[meta$Experiment=="Lab18",]

# %%
asv_de18=asv_all[rownames(asv_all) %in% meta_de18$UniqueID,]

# %%
asv_de=asv_all[rownames(asv_all) %in% meta_de$UniqueID,]

# %%
asv_de=asv_de[,colSums(asv_de)>0]

# %%
#make taxa list that just applies to de samples
taxa_de=taxa[rownames(taxa)%in% colnames(asv_de),]

# %%
taxa_de=as.matrix(taxa_de)

# %%
taxa_de=as.matrix(taxa_de)
meta_de=as.data.frame(meta_de)
row.names(meta_de)=meta_de$UniqueID

# %%
OTU = otu_table((asv_de), taxa_are_rows = FALSE)
TAX = tax_table(taxa_de)
SAMP=sample_data(meta_de)

# %%
SAMP$Species=gsub("MM", "AM", SAMP$Species)

# %%
DE = phyloseq(OTU, TAX, SAMP)

# %%
DE17=subset_samples(DE, Year=="2017")
DE17=prune_taxa(taxa_sums(DE17)>0, DE17)


DE18=subset_samples(DE, Year=="2018")
DE18=prune_taxa(taxa_sums(DE18)>0, DE18)

# %%
DE18CV=subset_samples(DE18, Species=="CV")
DE18CV=prune_taxa(taxa_sums(DE18CV)>0, DE18CV)

# %%
plot_richness(DE18CV, color="Treatment2_Diversity", x="Treatment1_Density", measures= "Observed")+
geom_point(size=6)+
#geom_vline(xintercept = 16)+
theme_bw()+
scale_x_discrete(limits = rev)+
theme(legend.position="top", panel.border = element_blank(), 
          panel.grid.major.x = element_blank(), 
          panel.grid.minor.x = element_blank(),
          axis.line=element_line(color="black"), axis.text=element_text(angle=90),
          text = element_text(size=20))
# Out:
# Warning message in estimate_richness(physeq, split = TRUE, measures = measures):
# “The data you have provided does not have
# any singletons. This is highly suspicious. Results of richness
# estimates (for example) are probably unreliable, or wrong, if you have already
# trimmed low-abundance taxa from the data.
#
# We recommended that you find the un-trimmed data and retry.”
# plot without title

# %%
plot_richness(DE17, color="Experiment", x="Site", measures= "Observed")+
geom_point(size=6)+
#geom_vline(xintercept = 16)+
theme_bw()+
scale_x_discrete(limits = rev)+
theme(legend.position="top", panel.border = element_blank(), 
          panel.grid.major.x = element_blank(), 
          panel.grid.minor.x = element_blank(),
          axis.line=element_line(color="black"), axis.text=element_text(angle=90),
          text = element_text(size=20))
# Out:
# plot without title

# %%
mycolors= colorRampPalette(brewer.pal(8, "Accent"))(4)

# %%
plot_richness(DE, color="Species", x="Species", measures= "Observed")+
geom_point(size=6)+
#geom_vline(xintercept = 16)+
theme_bw()+
scale_color_manual(values=mycolors)+
facet_grid(.~Experiment)+
scale_x_discrete(limits = rev)+
theme(legend.position="top", panel.border = element_blank(), 
          panel.grid.major.x = element_blank(), 
          panel.grid.minor.x = element_blank(),
          axis.line=element_line(color="black"), axis.text=element_text(angle=90),
          text = element_text(size=30))
# Out:
# plot without title

# %%
DE18.dist=phyloseq::distance(DE18, "bray", type="samples")
DE18CV.dist=phyloseq::distance(DE18CV, "bray", type="samples")
DE17.dist=phyloseq::distance(DE17, "bray", type="samples")

# %%
DE.dist=phyloseq::distance(DE, "bray", type="samples")

# %%
sampledf=as.data.frame(sample_data(DE))

# %%
bd.Species=betadisper(DE.dist, sampledf$Species)

# %%
permutest(bd.Species)
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#            Df Sum Sq  Mean Sq      F N.Perm Pr(>F)
# Groups      3 0.6640 0.221320 11.774    999  0.001 ***
# Residuals 208 3.9098 0.018797
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
bd.Species
# Out:
# 	Homogeneity of multivariate dispersions
#
# Call: betadisper(d = DE.dist, group = sampledf$Species)
#
# No. of Positive Eigenvalues: 162
# No. of Negative Eigenvalues: 49
#
# Average distance to median:
#     CV     IR     MB     MM
# 0.5716 0.4145 0.4838 0.5883
#
# Eigenvalues for PCoA axes:
# (Showing 8 of 211 eigenvalues)
#  PCoA1  PCoA2  PCoA3  PCoA4  PCoA5  PCoA6  PCoA7  PCoA8
# 15.233  7.616  5.598  4.547  3.582  2.513  1.998  1.814

# %%
pdf(width=20, height=10, file="~/Documents/DE/Figures/Dispersion.pdf")
boxplot(bd.Species)
dev.off()
# Out:
# pdf
#   2

# %%
# Out:
# plot without title

# %%
dev.off()
# Out:
# pdf
#   3

# %%
TukeyHSD(bd.Species)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = distances ~ group, data = df)
#
# $group
#              diff         lwr         upr     p adj
# IR-CV -0.15712523 -0.22744265 -0.08680781 0.0000002
# MB-CV -0.08783205 -0.23533112  0.05966701 0.4142230
# MM-CV  0.01669254 -0.13080652  0.16419161 0.9912141
# MB-IR  0.06929318 -0.08950591  0.22809227 0.6713476
# MM-IR  0.17381777  0.01501868  0.33261687 0.0257363
# MM-MB  0.10452460 -0.10048415  0.30953334 0.5509387

# %%
bd.Species=betadisper(DE18.dist, sampledf$Species)
bd.Bucket=betadisper(DE18.dist, sampledf$Color_Bucket)

# %%
anova(bd.Species)
# Out:
#           Df Sum Sq   Mean Sq    F value  Pr(>F)
# Groups     3 0.403141 0.13438033 4.841969 0.003510159
# Residuals 96 2.664311 0.02775324       NA          NA

# %%
permutest(bd.Species)
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df  Sum Sq  Mean Sq     F N.Perm Pr(>F)
# Groups     3 0.40314 0.134380 4.842    999  0.003 **
# Residuals 96 2.66431 0.027753
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
TukeyHSD(bd.Species)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = distances ~ group, data = df)
#
# $group
#              diff         lwr         upr     p adj
# IR-CV -0.13468563 -0.23264138 -0.03672988 0.0028499
# MB-CV -0.06491591 -0.25171019  0.12187837 0.8002775
# MM-CV  0.03960876 -0.14718552  0.22640304 0.9451364
# MB-IR  0.06976972 -0.12502546  0.26456491 0.7853288
# MM-IR  0.17429439 -0.02050079  0.36908958 0.0963240
# MM-MB  0.10452467 -0.14695483  0.35600417 0.6984577

# %%
boxplot(bd.Species)
# Out:
# plot without title

# %%
sampledf=as.data.frame(sample_data(DE18CV))

# %%
sample_data(DE18)
# Out:
#                           V1  UniqueID                  Experiment Year Site
# 2018__HIGH_MONO_HM1O73_CV 116 2018__HIGH_MONO_HM1O73_CV Lab18      2018
# 2018__HIGH_MONO_HM1W15_CV 113 2018__HIGH_MONO_HM1W15_CV Lab18      2018
# 2018__HIGH_MONO_HM1W33_CV 114 2018__HIGH_MONO_HM1W33_CV Lab18      2018
# 2018__HIGH_MONO_HM1W96_CV 115 2018__HIGH_MONO_HM1W96_CV Lab18      2018
# 2018__HIGH_MONO_HM4Y44_CV 121 2018__HIGH_MONO_HM4Y44_CV Lab18      2018
# 2018__HIGH_MONO_HM4Y53_CV 122 2018__HIGH_MONO_HM4Y53_CV Lab18      2018
# 2018__HIGH_MONO_HM8O20_CV 123 2018__HIGH_MONO_HM8O20_CV Lab18      2018
# 2018__HIGH_MONO_HM8O34_CV 124 2018__HIGH_MONO_HM8O34_CV Lab18      2018
# 2018__HIGH_MONO_HM8O66_CV 125 2018__HIGH_MONO_HM8O66_CV Lab18      2018
# 2018__HIGH_MONO_HM8Y28_CV 126 2018__HIGH_MONO_HM8Y28_CV Lab18      2018
# 2018__HIGH_MONO_HM8Y52_CV 127 2018__HIGH_MONO_HM8Y52_CV Lab18      2018
# 2018__HIGH_POLY_HP1W26_CV 129 2018__HIGH_POLY_HP1W26_CV Lab18      2018
# 2018__HIGH_POLY_HP1W5_CV  128 2018__HIGH_POLY_HP1W5_CV  Lab18      2018
# 2018__HIGH_POLY_HP1W62_CV 200 2018__HIGH_POLY_HP1W62_CV Lab18      2018
# 2018__HIGH_POLY_HP1W63_CV 130 2018__HIGH_POLY_HP1W63_CV Lab18      2018
# 2018__HIGH_POLY_HP1Y33_IR 131 2018__HIGH_POLY_HP1Y33_IR Lab18      2018
# 2018__HIGH_POLY_HP1Y55_IR 132 2018__HIGH_POLY_HP1Y55_IR Lab18      2018
# 2018__HIGH_POLY_HP1Y64_IR 133 2018__HIGH_POLY_HP1Y64_IR Lab18      2018
# 2018__HIGH_POLY_HP1Y75_IR 134 2018__HIGH_POLY_HP1Y75_IR Lab18      2018
# 2018__HIGH_POLY_HP1Y84_IR 135 2018__HIGH_POLY_HP1Y84_IR Lab18      2018
# 2018__HIGH_POLY_HP3B59_CV 136 2018__HIGH_POLY_HP3B59_CV Lab18      2018
# 2018__HIGH_POLY_HP3B65_CV 137 2018__HIGH_POLY_HP3B65_CV Lab18      2018
# 2018__HIGH_POLY_HP3W36_CV 138 2018__HIGH_POLY_HP3W36_CV Lab18      2018
# 2018__HIGH_POLY_HP3W36_IR 142 2018__HIGH_POLY_HP3W36_IR Lab18      2018
# 2018__HIGH_POLY_HP3W37_IR 143 2018__HIGH_POLY_HP3W37_IR Lab18      2018
# 2018__HIGH_POLY_HP3W4_IR  140 2018__HIGH_POLY_HP3W4_IR  Lab18      2018
# 2018__HIGH_POLY_HP3W40_IR 144 2018__HIGH_POLY_HP3W40_IR Lab18      2018
# 2018__HIGH_POLY_HP3W45_CV 202 2018__HIGH_POLY_HP3W45_CV Lab18      2018
# 2018__HIGH_POLY_HP3W61_CV 139 2018__HIGH_POLY_HP3W61_CV Lab18      2018
# 2018__HIGH_POLY_HP3W9_IR  141 2018__HIGH_POLY_HP3W9_IR  Lab18      2018
# ⋮                         ⋮   ⋮                         ⋮          ⋮    ⋮
# 2018__LOW_POLY_LP51_MB    215 2018__LOW_POLY_LP51_MB    Lab18      2018
# 2018__LOW_POLY_LP52_MB    213 2018__LOW_POLY_LP52_MB    Lab18      2018
# 2018__LOW_POLY_LP53_MM    188 2018__LOW_POLY_LP53_MM    Lab18      2018
# 2018__LOW_POLY_LP5G15_CV  182 2018__LOW_POLY_LP5G15_CV  Lab18      2018
# 2018__LOW_POLY_LP5G9_CV   206 2018__LOW_POLY_LP5G9_CV   Lab18      2018
# 2018__LOW_POLY_LP5O45_CV  207 2018__LOW_POLY_LP5O45_CV  Lab18      2018
# 2018__LOW_POLY_LP5O51_CV  210 2018__LOW_POLY_LP5O51_CV  Lab18      2018
# 2018__LOW_POLY_LP5O78_CV  208 2018__LOW_POLY_LP5O78_CV  Lab18      2018
# 2018__LOW_POLY_LP5O83_CV  180 2018__LOW_POLY_LP5O83_CV  Lab18      2018
# 2018__LOW_POLY_LP5W11_IR  184 2018__LOW_POLY_LP5W11_IR  Lab18      2018
# 2018__LOW_POLY_LP5W25_IR  185 2018__LOW_POLY_LP5W25_IR  Lab18      2018
# 2018__LOW_POLY_LP5W41_IR  186 2018__LOW_POLY_LP5W41_IR  Lab18      2018
# 2018__LOW_POLY_LP5W48_IR  187 2018__LOW_POLY_LP5W48_IR  Lab18      2018
# 2018__LOW_POLY_LP5W5_IR   183 2018__LOW_POLY_LP5W5_IR   Lab18      2018
# 2018__LOW_POLY_LP5Y92_CV  181 2018__LOW_POLY_LP5Y92_CV  Lab18      2018
# 2018__LOW_POLY_LP71_MB    217 2018__LOW_POLY_LP71_MB    Lab18      2018
# 2018__LOW_POLY_LP72_MB    211 2018__LOW_POLY_LP72_MB    Lab18      2018
# 2018__LOW_POLY_LP73_MB    212 2018__LOW_POLY_LP73_MB    Lab18      2018
# 2018__LOW_POLY_LP74_MM    214 2018__LOW_POLY_LP74_MM    Lab18      2018
# 2018__LOW_POLY_LP75_MM    198 2018__LOW_POLY_LP75_MM    Lab18      2018
# 2018__LOW_POLY_LP7O11_CV  189 2018__LOW_POLY_LP7O11_CV  Lab18      2018
# 2018__LOW_POLY_LP7O23_CV  190 2018__LOW_POLY_LP7O23_CV  Lab18      2018
# 2018__LOW_POLY_LP7O25_CV  191 2018__LOW_POLY_LP7O25_CV  Lab18      2018
# 2018__LOW_POLY_LP7O37_CV  192 2018__LOW_POLY_LP7O37_CV  Lab18      2018
# 2018__LOW_POLY_LP7Y16_IR  194 2018__LOW_POLY_LP7Y16_IR  Lab18      2018
# 2018__LOW_POLY_LP7Y17_IR  195 2018__LOW_POLY_LP7Y17_IR  Lab18      2018
# 2018__LOW_POLY_LP7Y74_IR  196 2018__LOW_POLY_LP7Y74_IR  Lab18      2018
# 2018__LOW_POLY_LP7Y8_CV   209 2018__LOW_POLY_LP7Y8_CV   Lab18      2018
# 2018__LOW_POLY_LP7Y88_IR  197 2018__LOW_POLY_LP7Y88_IR  Lab18      2018
# 2018__LOW_POLY_LP7Y94_IR  193 2018__LOW_POLY_LP7Y94_IR  Lab18      2018
#                           Treatment1_Density Treatment2_Diversity Color_Bucket
# 2018__HIGH_MONO_HM1O73_CV HIGH               MONO                 HM1
# 2018__HIGH_MONO_HM1W15_CV HIGH               MONO                 HM1
# 2018__HIGH_MONO_HM1W33_CV HIGH               MONO                 HM1
# 2018__HIGH_MONO_HM1W96_CV HIGH               MONO                 HM1
# 2018__HIGH_MONO_HM4Y44_CV HIGH               MONO                 HM4
# 2018__HIGH_MONO_HM4Y53_CV HIGH               MONO                 HM4
# 2018__HIGH_MONO_HM8O20_CV HIGH               MONO                 HM8
# 2018__HIGH_MONO_HM8O34_CV HIGH               MONO                 HM8
# 2018__HIGH_MONO_HM8O66_CV HIGH               MONO                 HM8
# 2018__HIGH_MONO_HM8Y28_CV HIGH               MONO                 HM8
# 2018__HIGH_MONO_HM8Y52_CV HIGH               MONO                 HM8
# 2018__HIGH_POLY_HP1W26_CV HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1W5_CV  HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1W62_CV HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1W63_CV HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1Y33_IR HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1Y55_IR HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1Y64_IR HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1Y75_IR HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP1Y84_IR HIGH               POLY                 HP1
# 2018__HIGH_POLY_HP3B59_CV HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3B65_CV HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W36_CV HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W36_IR HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W37_IR HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W4_IR  HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W40_IR HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W45_CV HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W61_CV HIGH               POLY                 HP3
# 2018__HIGH_POLY_HP3W9_IR  HIGH               POLY                 HP3
# ⋮                         ⋮                  ⋮                    ⋮
# 2018__LOW_POLY_LP51_MB    LOW                POLY                 LP5
# 2018__LOW_POLY_LP52_MB    LOW                POLY                 LP5
# 2018__LOW_POLY_LP53_MM    LOW                POLY                 LP5
# 2018__LOW_POLY_LP5G15_CV  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5G9_CV   LOW                POLY                 LP5
# 2018__LOW_POLY_LP5O45_CV  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5O51_CV  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5O78_CV  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5O83_CV  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5W11_IR  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5W25_IR  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5W41_IR  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5W48_IR  LOW                POLY                 LP5
# 2018__LOW_POLY_LP5W5_IR   LOW                POLY                 LP5
# 2018__LOW_POLY_LP5Y92_CV  LOW                POLY                 LP5
# 2018__LOW_POLY_LP71_MB    LOW                POLY                 LP7
# 2018__LOW_POLY_LP72_MB    LOW                POLY                 LP7
# 2018__LOW_POLY_LP73_MB    LOW                POLY                 LP7
# 2018__LOW_POLY_LP74_MM    LOW                POLY                 LP7
# 2018__LOW_POLY_LP75_MM    LOW                POLY                 LP7
# 2018__LOW_POLY_LP7O11_CV  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7O23_CV  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7O25_CV  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7O37_CV  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7Y16_IR  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7Y17_IR  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7Y74_IR  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7Y8_CV   LOW                POLY                 LP7
# 2018__LOW_POLY_LP7Y88_IR  LOW                POLY                 LP7
# 2018__LOW_POLY_LP7Y94_IR  LOW                POLY                 LP7
#                           Number Species RFTM_score peacrabs Phase_1_DO
# 2018__HIGH_MONO_HM1O73_CV O73    CV      0.0         0
# 2018__HIGH_MONO_HM1W15_CV W15    CV      0.0         0
# 2018__HIGH_MONO_HM1W33_CV W33    CV      0.0         0
# 2018__HIGH_MONO_HM1W96_CV W96    CV      0.0         0
# 2018__HIGH_MONO_HM4Y44_CV Y44    CV      0.0        NA
# 2018__HIGH_MONO_HM4Y53_CV Y53    CV      0.0        NA
# 2018__HIGH_MONO_HM8O20_CV O20    CV      0.0        NA
# 2018__HIGH_MONO_HM8O34_CV O34    CV      0.0        NA
# 2018__HIGH_MONO_HM8O66_CV O66    CV      0.0        NA
# 2018__HIGH_MONO_HM8Y28_CV Y28    CV      0.0        NA
# 2018__HIGH_MONO_HM8Y52_CV Y52    CV      0.0        NA
# 2018__HIGH_POLY_HP1W26_CV W26    CV      0.0        NA
# 2018__HIGH_POLY_HP1W5_CV  W5     CV      0.0        NA
# 2018__HIGH_POLY_HP1W62_CV W62    CV      0.5        NA
# 2018__HIGH_POLY_HP1W63_CV W63    CV      0.0        NA
# 2018__HIGH_POLY_HP1Y33_IR Y33    IR      0.0        NA
# 2018__HIGH_POLY_HP1Y55_IR Y55    IR      0.0        NA
# 2018__HIGH_POLY_HP1Y64_IR Y64    IR      0.0        NA
# 2018__HIGH_POLY_HP1Y75_IR Y75    IR      0.0        NA
# 2018__HIGH_POLY_HP1Y84_IR Y84    IR      0.0        NA
# 2018__HIGH_POLY_HP3B59_CV B59    CV      0.0        NA
# 2018__HIGH_POLY_HP3B65_CV B65    CV      0.0        NA
# 2018__HIGH_POLY_HP3W36_CV W36    CV      0.0        NA
# 2018__HIGH_POLY_HP3W36_IR W36    IR      0.0        NA
# 2018__HIGH_POLY_HP3W37_IR W37    IR      0.0        NA
# 2018__HIGH_POLY_HP3W4_IR  W4     IR      0.0        NA
# 2018__HIGH_POLY_HP3W40_IR W40    IR      0.0        NA
# 2018__HIGH_POLY_HP3W45_CV W45    CV      1.0        NA
# 2018__HIGH_POLY_HP3W61_CV W61    CV      0.0        NA
# 2018__HIGH_POLY_HP3W9_IR  W9     IR      0.0        NA
# ⋮                         ⋮      ⋮       ⋮          ⋮        ⋮
# 2018__LOW_POLY_LP51_MB    1      MB      4.0        NA
# 2018__LOW_POLY_LP52_MB    2      MB      3.0        NA
# 2018__LOW_POLY_LP53_MM    3      MM      0.0        NA
# 2018__LOW_POLY_LP5G15_CV  G15    CV      0.0        NA
# 2018__LOW_POLY_LP5G9_CV   G9     CV      0.5        NA
# 2018__LOW_POLY_LP5O45_CV  O45    CV      0.5        NA
# 2018__LOW_POLY_LP5O51_CV  O51    CV      1.0        NA
# 2018__LOW_POLY_LP5O78_CV  O78    CV      0.5        NA
# 2018__LOW_POLY_LP5O83_CV  O83    CV      0.0        NA
# 2018__LOW_POLY_LP5W11_IR  W11    IR      0.0        NA
# 2018__LOW_POLY_LP5W25_IR  W25    IR      0.0        NA
# 2018__LOW_POLY_LP5W41_IR  W41    IR      0.0        NA
# 2018__LOW_POLY_LP5W48_IR  W48    IR      0.0        NA
# 2018__LOW_POLY_LP5W5_IR   W5     IR      0.0        NA
# 2018__LOW_POLY_LP5Y92_CV  Y92    CV      0.0        NA
# 2018__LOW_POLY_LP71_MB    1      MB      5.0        NA
# 2018__LOW_POLY_LP72_MB    2      MB      2.0        NA
# 2018__LOW_POLY_LP73_MB    3      MB      2.0        NA
# 2018__LOW_POLY_LP74_MM    4      MM      3.0        NA
# 2018__LOW_POLY_LP75_MM    5      MM      0.0        NA
# 2018__LOW_POLY_LP7O11_CV  O11    CV      0.0        NA
# 2018__LOW_POLY_LP7O23_CV  O23    CV      0.0        NA
# 2018__LOW_POLY_LP7O25_CV  O25    CV      0.0        NA
# 2018__LOW_POLY_LP7O37_CV  O37    CV      0.0        NA
# 2018__LOW_POLY_LP7Y16_IR  Y16    IR      0.0        NA
# 2018__LOW_POLY_LP7Y17_IR  Y17    IR      0.0        NA
# 2018__LOW_POLY_LP7Y74_IR  Y74    IR      0.0        NA
# 2018__LOW_POLY_LP7Y8_CV   Y8     CV      0.5        NA
# 2018__LOW_POLY_LP7Y88_IR  Y88    IR      0.0        NA
# 2018__LOW_POLY_LP7Y94_IR  Y94    IR      0.0        NA
#                           Phase_1_temp Phase_2_DO Phase_2_Temp
# 2018__HIGH_MONO_HM1O73_CV
# 2018__HIGH_MONO_HM1W15_CV
# 2018__HIGH_MONO_HM1W33_CV
# 2018__HIGH_MONO_HM1W96_CV
# 2018__HIGH_MONO_HM4Y44_CV
# 2018__HIGH_MONO_HM4Y53_CV
# 2018__HIGH_MONO_HM8O20_CV
# 2018__HIGH_MONO_HM8O34_CV
# 2018__HIGH_MONO_HM8O66_CV
# 2018__HIGH_MONO_HM8Y28_CV
# 2018__HIGH_MONO_HM8Y52_CV
# 2018__HIGH_POLY_HP1W26_CV
# 2018__HIGH_POLY_HP1W5_CV
# 2018__HIGH_POLY_HP1W62_CV
# 2018__HIGH_POLY_HP1W63_CV
# 2018__HIGH_POLY_HP1Y33_IR
# 2018__HIGH_POLY_HP1Y55_IR
# 2018__HIGH_POLY_HP1Y64_IR
# 2018__HIGH_POLY_HP1Y75_IR
# 2018__HIGH_POLY_HP1Y84_IR
# 2018__HIGH_POLY_HP3B59_CV
# 2018__HIGH_POLY_HP3B65_CV
# 2018__HIGH_POLY_HP3W36_CV
# 2018__HIGH_POLY_HP3W36_IR
# 2018__HIGH_POLY_HP3W37_IR
# 2018__HIGH_POLY_HP3W4_IR
# 2018__HIGH_POLY_HP3W40_IR
# 2018__HIGH_POLY_HP3W45_CV
# 2018__HIGH_POLY_HP3W61_CV
# 2018__HIGH_POLY_HP3W9_IR
# ⋮                         ⋮            ⋮          ⋮
# 2018__LOW_POLY_LP51_MB
# 2018__LOW_POLY_LP52_MB
# 2018__LOW_POLY_LP53_MM
# 2018__LOW_POLY_LP5G15_CV
# 2018__LOW_POLY_LP5G9_CV
# 2018__LOW_POLY_LP5O45_CV
# 2018__LOW_POLY_LP5O51_CV
# 2018__LOW_POLY_LP5O78_CV
# 2018__LOW_POLY_LP5O83_CV
# 2018__LOW_POLY_LP5W11_IR
# 2018__LOW_POLY_LP5W25_IR
# 2018__LOW_POLY_LP5W41_IR
# 2018__LOW_POLY_LP5W48_IR
# 2018__LOW_POLY_LP5W5_IR
# 2018__LOW_POLY_LP5Y92_CV
# 2018__LOW_POLY_LP71_MB
# 2018__LOW_POLY_LP72_MB
# 2018__LOW_POLY_LP73_MB
# 2018__LOW_POLY_LP74_MM
# 2018__LOW_POLY_LP75_MM
# 2018__LOW_POLY_LP7O11_CV
# 2018__LOW_POLY_LP7O23_CV
# 2018__LOW_POLY_LP7O25_CV
# 2018__LOW_POLY_LP7O37_CV
# 2018__LOW_POLY_LP7Y16_IR
# 2018__LOW_POLY_LP7Y17_IR
# 2018__LOW_POLY_LP7Y74_IR
# 2018__LOW_POLY_LP7Y8_CV
# 2018__LOW_POLY_LP7Y88_IR
# 2018__LOW_POLY_LP7Y94_IR
#                           Overall_treatment RFTM_pa
# 2018__HIGH_MONO_HM1O73_CV                   0
# 2018__HIGH_MONO_HM1W15_CV                   0
# 2018__HIGH_MONO_HM1W33_CV                   0
# 2018__HIGH_MONO_HM1W96_CV                   0
# 2018__HIGH_MONO_HM4Y44_CV                   0
# 2018__HIGH_MONO_HM4Y53_CV                   0
# 2018__HIGH_MONO_HM8O20_CV                   0
# 2018__HIGH_MONO_HM8O34_CV                   0
# 2018__HIGH_MONO_HM8O66_CV                   0
# 2018__HIGH_MONO_HM8Y28_CV                   0
# 2018__HIGH_MONO_HM8Y52_CV                   0
# 2018__HIGH_POLY_HP1W26_CV                   0
# 2018__HIGH_POLY_HP1W5_CV                    0
# 2018__HIGH_POLY_HP1W62_CV                   1
# 2018__HIGH_POLY_HP1W63_CV                   0
# 2018__HIGH_POLY_HP1Y33_IR                   0
# 2018__HIGH_POLY_HP1Y55_IR                   0
# 2018__HIGH_POLY_HP1Y64_IR                   0
# 2018__HIGH_POLY_HP1Y75_IR                   0
# 2018__HIGH_POLY_HP1Y84_IR                   0
# 2018__HIGH_POLY_HP3B59_CV                   0
# 2018__HIGH_POLY_HP3B65_CV                   0
# 2018__HIGH_POLY_HP3W36_CV                   0
# 2018__HIGH_POLY_HP3W36_IR                   0
# 2018__HIGH_POLY_HP3W37_IR                   0
# 2018__HIGH_POLY_HP3W4_IR                    0
# 2018__HIGH_POLY_HP3W40_IR                   0
# 2018__HIGH_POLY_HP3W45_CV                   1
# 2018__HIGH_POLY_HP3W61_CV                   0
# 2018__HIGH_POLY_HP3W9_IR                    0
# ⋮                         ⋮                 ⋮
# 2018__LOW_POLY_LP51_MB                      1
# 2018__LOW_POLY_LP52_MB                      1
# 2018__LOW_POLY_LP53_MM                      0
# 2018__LOW_POLY_LP5G15_CV                    0
# 2018__LOW_POLY_LP5G9_CV                     1
# 2018__LOW_POLY_LP5O45_CV                    1
# 2018__LOW_POLY_LP5O51_CV                    1
# 2018__LOW_POLY_LP5O78_CV                    1
# 2018__LOW_POLY_LP5O83_CV                    0
# 2018__LOW_POLY_LP5W11_IR                    0
# 2018__LOW_POLY_LP5W25_IR                    0
# 2018__LOW_POLY_LP5W41_IR                    0
# 2018__LOW_POLY_LP5W48_IR                    0
# 2018__LOW_POLY_LP5W5_IR                     0
# 2018__LOW_POLY_LP5Y92_CV                    0
# 2018__LOW_POLY_LP71_MB                      1
# 2018__LOW_POLY_LP72_MB                      1
# 2018__LOW_POLY_LP73_MB                      1
# 2018__LOW_POLY_LP74_MM                      1
# 2018__LOW_POLY_LP75_MM                      0
# 2018__LOW_POLY_LP7O11_CV                    0
# 2018__LOW_POLY_LP7O23_CV                    0
# 2018__LOW_POLY_LP7O25_CV                    0
# 2018__LOW_POLY_LP7O37_CV                    0
# 2018__LOW_POLY_LP7Y16_IR                    0
# 2018__LOW_POLY_LP7Y17_IR                    0
# 2018__LOW_POLY_LP7Y74_IR                    0
# 2018__LOW_POLY_LP7Y8_CV                     1
# 2018__LOW_POLY_LP7Y88_IR                    0
# 2018__LOW_POLY_LP7Y94_IR                    0

# %%
bd.Treatment1_Density=betadisper(DE18CV.dist, sampledf$Treatment1_Density)
bd.Treatment2_Diversity=betadisper(DE18CV.dist, sampledf$Treatment2_Diversity)

# %%
sampledf=as.data.frame(sample_data(DE17))

# %%
bd.RFTM_pa=betadisper(DE17.dist, sampledf$RFTM_pa)
bd.RFTM_peacrab=betadisper(DE17.dist, sampledf$peacrabs)

# %%
permutest(bd.RFTM_peacrab)
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#            Df  Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups      1 0.00074 0.0007444 0.0582    999  0.809
# Residuals 110 1.40570 0.0127791

# %%
permutest(bd.RFTM_pa)
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#            Df  Sum Sq  Mean Sq      F N.Perm Pr(>F)
# Groups      1 0.02247 0.022468 1.7777    999  0.189
# Residuals 110 1.39031 0.012639

# %%
plot(bd.RFTM_pa)
# Out:
# Plot with title “bd.RFTM_pa”

# %%
boxplot(bd.RFTM_pa)
# Out:
# plot without title

# %%
bd.Treatment1_Density
# Out:
# 	Homogeneity of multivariate dispersions
#
# Call: betadisper(d = DE18CV.dist, group = sampledf$Treatment1_Density)
#
# No. of Positive Eigenvalues: 51
# No. of Negative Eigenvalues: 6
#
# Average distance to median:
#   HIGH    LOW
# 0.5715 0.5052
#
# Eigenvalues for PCoA axes:
# (Showing 8 of 57 eigenvalues)
#  PCoA1  PCoA2  PCoA3  PCoA4  PCoA5  PCoA6  PCoA7  PCoA8
# 4.2787 2.0655 1.6253 1.2783 0.9977 0.7210 0.6446 0.5681

# %%
anova(bd.Treatment1_Density)
# Out:
#           Df Sum Sq     Mean Sq    F value  Pr(>F)
# Groups     1 0.06294805 0.06294805 2.870758 0.09575757
# Residuals 56 1.22793041 0.02192733       NA         NA

# %%
anova(bd.Treatment2_Diversity)
# Out:
#           Df Sum Sq      Mean Sq     F value   Pr(>F)
# Groups     1 0.004600282 0.004600282 0.1961752 0.6595323
# Residuals 56 1.313192566 0.023449867        NA        NA

# %%
permutest(bd.Treatment1_Density)
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df  Sum Sq  Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.06295 0.062948 2.8708    999  0.111
# Residuals 56 1.22793 0.021927

# %%
distances=as.data.frame(bd.Treatment1_Density$distances)

# %%
colnames(distances)="distance_from_centroid"
distances=merge(distances, meta, by.x="row.names", by.y="UniqueID")

# %%
ggplot(distances, aes(y = distance_from_centroid, x = Treatment1_Density, col=Species)) +
       geom_point(size=10)+

theme_bw()+
 
theme(legend.position="right", panel.border = element_blank(), 
          panel.grid.major.x = element_blank(), 
          panel.grid.minor.x = element_blank(),
    
          axis.ticks.x=element_blank(), axis.line=element_line(color="black"), axis.text=element_text(color="black"),
          text = element_text(size=20))+
ylab("Distance from centroid")
# Out:
# plot without title

# %%
bd.Species
# Out:
# 	Homogeneity of multivariate dispersions
#
# Call: betadisper(d = DE18.dist, group = sampledf$Species)
#
# No. of Positive Eigenvalues: 80
# No. of Negative Eigenvalues: 19
#
# Average distance to median:
#     CV     IR     MB     MM
# 0.5492 0.4145 0.4843 0.5888
#
# Eigenvalues for PCoA axes:
# (Showing 8 of 99 eigenvalues)
#  PCoA1  PCoA2  PCoA3  PCoA4  PCoA5  PCoA6  PCoA7  PCoA8
# 11.117  4.158  2.138  1.895  1.628  1.134  1.022  1.017

# %%
distances=as.data.frame(bd.Species$distances)

# %%
distances
# Out:
#                           bd.Bucket$distances
# 2018__HIGH_MONO_HM1O73_CV 0.1756692
# 2018__HIGH_MONO_HM1W15_CV 0.7355004
# 2018__HIGH_MONO_HM1W33_CV 0.5598616
# 2018__HIGH_MONO_HM1W96_CV 0.2577098
# 2018__HIGH_MONO_HM4Y44_CV 0.2165486
# 2018__HIGH_MONO_HM4Y53_CV 0.2165486
# 2018__HIGH_MONO_HM8O20_CV 0.6140257
# 2018__HIGH_MONO_HM8O34_CV 0.4373556
# 2018__HIGH_MONO_HM8O66_CV 0.4553934
# 2018__HIGH_MONO_HM8Y28_CV 0.5632426
# 2018__HIGH_MONO_HM8Y52_CV 0.6382888
# 2018__HIGH_POLY_HP1W26_CV 0.8053237
# 2018__HIGH_POLY_HP1W5_CV  0.7175767
# 2018__HIGH_POLY_HP1W62_CV 0.7230601
# 2018__HIGH_POLY_HP1W63_CV 0.7247761
# 2018__HIGH_POLY_HP1Y33_IR 0.4359692
# 2018__HIGH_POLY_HP1Y55_IR 0.3661199
# 2018__HIGH_POLY_HP1Y64_IR 0.4156102
# 2018__HIGH_POLY_HP1Y75_IR 0.3208128
# 2018__HIGH_POLY_HP1Y84_IR 0.4706076
# 2018__HIGH_POLY_HP3B59_CV 0.6330178
# 2018__HIGH_POLY_HP3B65_CV 0.6399508
# 2018__HIGH_POLY_HP3W36_CV 0.4986110
# 2018__HIGH_POLY_HP3W36_IR 0.6272464
# 2018__HIGH_POLY_HP3W37_IR 0.4921698
# 2018__HIGH_POLY_HP3W4_IR  0.4217104
# 2018__HIGH_POLY_HP3W40_IR 0.4855728
# 2018__HIGH_POLY_HP3W45_CV 0.7195094
# 2018__HIGH_POLY_HP3W61_CV 0.7040120
# 2018__HIGH_POLY_HP3W9_IR  0.5217112
# ⋮                         ⋮
# 2018__LOW_POLY_LP51_MB    0.5836902
# 2018__LOW_POLY_LP52_MB    0.5263913
# 2018__LOW_POLY_LP53_MM    0.7423477
# 2018__LOW_POLY_LP5G15_CV  0.5332757
# 2018__LOW_POLY_LP5G9_CV   0.4791471
# 2018__LOW_POLY_LP5O45_CV  0.4727696
# 2018__LOW_POLY_LP5O51_CV  0.5017653
# 2018__LOW_POLY_LP5O78_CV  0.4646792
# 2018__LOW_POLY_LP5O83_CV  0.6891164
# 2018__LOW_POLY_LP5W11_IR  0.4792319
# 2018__LOW_POLY_LP5W25_IR  0.6528241
# 2018__LOW_POLY_LP5W41_IR  0.6342870
# 2018__LOW_POLY_LP5W48_IR  0.6575739
# 2018__LOW_POLY_LP5W5_IR   0.6074045
# 2018__LOW_POLY_LP5Y92_CV  0.5739076
# 2018__LOW_POLY_LP71_MB    0.5021812
# 2018__LOW_POLY_LP72_MB    0.5151794
# 2018__LOW_POLY_LP73_MB    0.4369025
# 2018__LOW_POLY_LP74_MM    0.4746054
# 2018__LOW_POLY_LP75_MM    0.4391164
# 2018__LOW_POLY_LP7O11_CV  0.4941623
# 2018__LOW_POLY_LP7O23_CV  0.5538189
# 2018__LOW_POLY_LP7O25_CV  0.7451904
# 2018__LOW_POLY_LP7O37_CV  0.7454882
# 2018__LOW_POLY_LP7Y16_IR  0.7180933
# 2018__LOW_POLY_LP7Y17_IR  0.7005545
# 2018__LOW_POLY_LP7Y74_IR  0.7207048
# 2018__LOW_POLY_LP7Y8_CV   0.4813085
# 2018__LOW_POLY_LP7Y88_IR  0.7030765
# 2018__LOW_POLY_LP7Y94_IR  0.7199991

# %%
colnames(distances)="distance_from_centroid"

# %%
distances=merge(distances, meta, by.x="row.names", by.y="UniqueID")

# %%
ggplot(distances, aes(y = distance_from_centroid, x = Species, col=Species)) +
       geom_point(size=10)+

theme_bw()+
 
theme(legend.position="right", panel.border = element_blank(), 
          panel.grid.major.x = element_blank(), 
          panel.grid.minor.x = element_blank(),
    
          axis.ticks.x=element_blank(), axis.line=element_line(color="black"), axis.text=element_text(color="black"),
          text = element_text(size=20))+
ylab("Distance from centroid")
# Out:
# plot without title
